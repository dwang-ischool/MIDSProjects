# %%
# %matplotlib inline
import sys
print(sys.version)
import numpy as np
print(np.__version__)
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt
import csv
# Out:
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 12:04:33)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# 1.14.0
# 0.22.0

# %%
tables1 = pd.read_html("https://www.boxofficemojo.com/alltime/world/?pagenum=1&p=.htm")
testing1 = tables1[1]
testing1.head()
# Out:
#       0                             1       2          3             4  \
# 0  Rank                         Title  Studio  Worldwide  Domestic / %
# 1     1                        Avatar     Fox   $2,788.0        $760.5
# 2     2                       Titanic    Par.   $2,187.5        $659.4
# 3     3  Star Wars: The Force Awakens      BV   $2,068.2        $936.7
# 4     4        Avengers: Infinity War      BV   $2,044.2        $677.5
#
#               5         6      7      8
# 0  Overseas / %     Year^    NaN    NaN
# 1         27.3%  $2,027.5  72.7%  2009^
# 2         30.1%  $1,528.1  69.9%  1997^
# 3         45.3%  $1,131.6  54.7%   2015
# 4         33.1%  $1,366.6  66.9%   2018

# %%
table = pd.read_html("https://www.boxofficemojo.com/people/?view=Actor&pagenum=1&sort=sumgross&order=DESC&&p=.htm")
actors = table[1]
actors.drop(0, axis = 0, inplace = True)

for i in range(7,358):
    actors.drop(i, axis = 1, inplace = True)

actors.head(55)
# Out:
#       0                      1            2                   3           4  \
# 1   Row  Person(Click to view)  Total Gross  # Movies / Average  #1 Picture
# 2     1      Samuel L. Jackson     $5,721.9                  74       $77.3
# 3     2          Harrison Ford     $4,963.8                  42      $118.2
# 4     3     Robert Downey, Jr.     $4,959.1                  55       $90.2
# 5     4              Tom Hanks     $4,605.7                  48       $96.0
# 6     5         Morgan Freeman     $4,522.3                  63       $71.8
# 7     6     Scarlett Johansson     $4,384.5                  42      $104.4
# 8     7            Andy Serkis     $4,357.6                  26      $167.6
# 9     8        Anthony Daniels     $4,040.9                   9      $449.0
# 10    9             Tom Cruise     $3,839.0                  40       $96.0
# 11   10           Eddie Murphy     $3,811.1                  39       $97.7
# ...

# %%
actors.drop(1, axis = 0, inplace = True)

# %%
#rename columns
actors.columns = ['Rank', 'primaryname', 'Total_Gross_Millions', 'Num_Movies', 'Average_Millions', 'Num_1_Picture', 'Gross_Millions']

#reindex by rank:
actors.set_index('Rank', inplace = True)
actors.head(50)
# Out:
#                primaryname Total_Gross_Millions Num_Movies Average_Millions  \
# Rank
# 1        Samuel L. Jackson             $5,721.9         74            $77.3
# 2            Harrison Ford             $4,963.8         42           $118.2
# 3       Robert Downey, Jr.             $4,959.1         55            $90.2
# 4                Tom Hanks             $4,605.7         48            $96.0
# 5           Morgan Freeman             $4,522.3         63            $71.8
# 6       Scarlett Johansson             $4,384.5         42           $104.4
# 7              Andy Serkis             $4,357.6         26           $167.6
# 8          Anthony Daniels             $4,040.9          9           $449.0
# 9               Tom Cruise             $3,839.0         40            $96.0
# 10            Eddie Murphy             $3,811.1         39            $97.7
# 11           Stanley Tucci             $3,775.9         54            $69.9
# ...

# %%
actors.to_csv('../Data/Top50BankableActors.csv')
